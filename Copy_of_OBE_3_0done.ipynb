# %%
import pandas as pd
obe = pd.read_csv('ObesityDataSet_problematic.csv')
obe
# Out:
#       Gender        Age    Height      Weight FAVC  FCVC  NCP       CAEC  \
# 0     Female  18.558106  1.620000   23.110524   no   2.0  3.0  Sometimes
# 1     Female   7.737623  1.520000   80.198638   no   3.0  3.0  Sometimes
# 2       Male -15.826249  1.800000   74.230213   no   2.0  3.0  Sometimes
# 3       Male  27.896518  1.800000   79.712764   no   3.0  3.0  Sometimes
# 4       Male  36.242844  1.780000   75.977602   no   2.0  1.0  Sometimes
# ...      ...        ...       ...         ...  ...   ...  ...        ...
# 2106  Female  25.560814  1.710730  126.345453  yes   3.0  3.0  Sometimes
# 2107  Female  35.558940  1.748584  138.106228  yes   3.0  3.0  Sometimes
# 2108  Female  20.508320  1.752206  145.393151  yes   3.0  3.0  Sometimes
# 2109  Female  23.230738  1.739450  139.777585  yes   3.0  3.0  Sometimes
# 2110  Female  48.548814  1.738836  140.455537  yes   3.0  3.0  Sometimes
#
#      SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# ...

# %%
obe['Gender']
# Out:
# 0       Female
# 1       Female
# 2         Male
# 3         Male
# 4         Male
#          ...
# 2106    Female
# 2107    Female
# 2108    Female
# 2109    Female
# 2110    Female
# Name: Gender, Length: 2111, dtype: object

# %%
obe[obe['Gender'].str.startswith('E')]
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Height, Weight, FAVC, FCVC, NCP, CAEC, SMOKE, CH2O, SCC, FAF, TUE, CALC, MTRANS, NObeyesdad]
# Index: []

# %%
obe.shape
# Out:
# (2111, 16)

# %%
obe['Age'].dtype
# Out:
# dtype('float64')

# %%
(obe['Gender'])
# Out:
# 0       Female
# 1       Female
# 2         Male
# 3         Male
# 4         Male
#          ...
# 2106    Female
# 2107    Female
# 2108    Female
# 2109    Female
# 2110    Female
# Name: Gender, Length: 2111, dtype: object

# %%
obe.groupby(['Gender','Age']).count()
# Out:
#                    Height  Weight  FAVC  FCVC  NCP  CAEC  SMOKE  CH2O  SCC  \
# Gender Age
# Female -27.292165       1       1     1     1    1     1      1     1    1
#        -24.566966       1       1     1     1    1     1      1     1    1
#        -20.698640       1       1     1     1    1     1      1     1    1
#        -20.496972       1       1     1     1    1     1      1     1    1
#        -19.385147       1       1     1     1    1     1      1     1    1
# ...                   ...     ...   ...   ...  ...   ...    ...   ...  ...
# Male    66.353392       1       1     1     1    1     1      1     1    1
#         70.416113       1       1     1     1    1     1      1     1    1
#         70.861566       1       1     1     1    1     1      1     1    1
#         78.623711       1       1     1     1    1     1      1     1    1
#         80.191043       1       1     1     1    1     1      1     1    1
#
#                    FAF  TUE  CALC  MTRANS  NObeyesdad
# ...

# %%
obe.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     23.792889     1.701677    85.910154     2.419043     2.685628
# std      16.423220     0.093305    36.791462     0.533927     0.778039
# min     -31.933551     1.450000   -29.396453     1.000000     1.000000
# 25%      12.860243     1.630000    59.641342     2.000000     2.658738
# 50%      23.069016     1.700499    84.489129     2.385502     3.000000
# 75%      34.799077     1.768464   112.539243     3.000000     3.000000
# max      80.191043     1.980000   212.467357     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
obe.describe(include='all')
# Out:
#        Gender          Age       Height       Weight  FAVC         FCVC  \
# count    2111  2111.000000  2111.000000  2111.000000  2111  2111.000000
# unique      2          NaN          NaN          NaN     2          NaN
# top      Male          NaN          NaN          NaN   yes          NaN
# freq     1068          NaN          NaN          NaN  1866          NaN
# mean      NaN    23.792889     1.701677    85.910154   NaN     2.419043
# std       NaN    16.423220     0.093305    36.791462   NaN     0.533927
# min       NaN   -31.933551     1.450000   -29.396453   NaN     1.000000
# 25%       NaN    12.860243     1.630000    59.641342   NaN     2.000000
# 50%       NaN    23.069016     1.700499    84.489129   NaN     2.385502
# 75%       NaN    34.799077     1.768464   112.539243   NaN     3.000000
# max       NaN    80.191043     1.980000   212.467357   NaN     3.000000
#
#                 NCP       CAEC SMOKE         CH2O   SCC          FAF  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.countplot(data=obe, x="NObeyesdad")
plt.xticks(rotation=45)
plt.title("Distribution of Obesity Levels")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

# Custom ordering ensures the snacking frequencies read naturally from left to right
snack_order = ['No', 'Sometimes', 'Frequently', 'Always']
# Filter out any unexpected categories if they exist, or just plot order safely
available_order = [o for o in snack_order if o in obe['CAEC'].unique()]

sns.countplot(data=obe, x='CAEC', hue='NObeyesdad', palette='viridis', order=available_order)

plt.title('Eating Between Meals (CAEC) Broken Down by Obesity Level', fontsize=14, fontweight='bold')
plt.xlabel('Frequency of Snacking Between Meals', fontsize=12)
plt.ylabel('Number of Individuals', fontsize=12)
plt.legend(title='Obesity Level', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Group by obesity level and find the average score for FAF and TUE
avg_habits = obe.groupby('NObeyesdad')[['FAF', 'TUE']].mean().reset_index()

# 2. Reshape ("melt") the data so Seaborn can cleanly plot both lines
avg_habits_melted = avg_habits.melt(id_vars='NObeyesdad', var_name='Habit', value_name='Average Score')

plt.figure(figsize=(12, 6))

# Plotting trends across the categories
sns.pointplot(data=avg_habits_melted, x='NObeyesdad', y='Average Score', hue='Habit',
              markers=['o', 's'], linestyles=['-', '--'], palette='Dark2')

plt.title('Average Physical Activity (FAF) vs. Technology Time (TUE) by Weight Category', fontsize=14, fontweight='bold')
plt.xlabel('Weight Category (NObeyesdad)', fontsize=12)
plt.ylabel('Average Feature Score', fontsize=12)
plt.xticks(rotation=30, ha='right')
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read dataset
page = pd.read_csv("ObesityDataSet_problematic.csv")

plt.figure(figsize=(18,5))

# ======================================
# 1. Pie Chart (Obesity Level Distribution)
# ======================================
plt.subplot(1,3,1)

page["NObeyesdad"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Obesity Level Distribution")
plt.ylabel("")

# ======================================
# 2. Histogram (Weight Distribution)
# ======================================
plt.subplot(1,3,2)

plt.hist(page["Weight"],
         bins=20,
         edgecolor="black")

plt.title("Obesity Level Distribution")
plt.xlabel("Weight (kg)")
plt.ylabel("Frequency")

# ======================================
# 3. Box Plot (Weight)
# ======================================
plt.subplot(1,3,3)

plt.boxplot(page["Weight"])

plt.title("Box Plot of obesity level")
plt.ylabel("Weight (kg)")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import polyfit

b, m = polyfit(obe.Height, obe.Weight, 1)

plt.plot(obe.Height, obe.Weight, '.')

plt.plot(obe.Height, b + m * obe.Height, '-')

plt.xlabel('Height ')
plt.ylabel('Weight ')
plt.title('Scatterplot: Height vs Weight')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = obe.corr(numeric_only=True)

plt.figure(figsize=(10, 8))

sns.heatmap(corr,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            annot=True,
            fmt=".2f",
            cmap="rocket")


plt.title('Correlation Heatmap for Obesity Dataset')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))


sns.countplot(y=obe['NObeyesdad'],
              hue=obe['NObeyesdad'],
              order=obe['NObeyesdad'].value_counts().index,
              palette='Set2',
              legend=False)

plt.xlabel('Count ')
plt.ylabel('Obesity Level ')
plt.title('Number of People in Each Obesity Level')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check for missing values
print(obe.isnull().sum())

# Heatmap for missing values
plt.figure(figsize=(10, 6))
sns.heatmap(obe.isnull(), cmap="tab20b", cbar=False).set_title('Overview of Missing Values in the Obesity Dataset')
plt.show()
# Out:
# Gender        0
# Age           0
# Height        0
# Weight        0
# FAVC          0
# FCVC          0
# NCP           0
# CAEC          0
# SMOKE         0
# CH2O          0
# SCC           0
# FAF           0
# TUE           0
# CALC          0
# MTRANS        0
# NObeyesdad    0
# dtype: int64

# %%
obe_cleaned = obe

# %%
#Step 1: Visualizing Outliers using Boxplots
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizing outliers using boxplots for continuous numerical features
plt.figure(figsize=(10, 6))

# We select only Age, Height, and Weight for the boxplot
sns.boxplot(data=obe_cleaned[['Age', 'Height', 'Weight']], palette="Set2")

plt.title('Figure: Boxplot for Detecting Outliers in Numerical Features')
plt.ylabel('Values')
plt.show()

# %%
print("Duplicate rows before:", obe.duplicated().sum())

obe = obe.drop_duplicates()

print("Duplicate rows after:", obe.duplicated().sum())
# Out:
# Duplicate rows before: 0
# Duplicate rows after: 0

# %%
# Calculating Outliers for the 'Weight' column using the IQR Method
Q1 = obe_cleaned['Weight'].quantile(0.25)
Q3 = obe_cleaned['Weight'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to find the outlier rows
outliers_weight = obe_cleaned[(obe_cleaned['Weight'] < lower_bound) | (obe_cleaned['Weight'] > upper_bound)]

print("--- Outlier Detection using IQR ---")
print(f"Lower Bound for Weight: {lower_bound:.2f}")
print(f"Upper Bound for Weight: {upper_bound:.2f}")
print(f"Total number of statistical outliers in Weight: {outliers_weight.shape[0]} rows")

# Note for report:
# Since this is an Obesity dataset, "extreme" weights are actual target classes (e.g., Obesity Type III).
# Therefore, dropping these outliers would result in data loss for critical categories. We will keep them.
# Out:
# --- Outlier Detection using IQR ---
# Lower Bound for Weight: -19.71
# Upper Bound for Weight: 191.89
# Total number of statistical outliers in Weight: 5 rows

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# 1. Encode the target variable: Convert 'NObeyesdad' (Obesity Level) to numeric labels (0, 1, 2, 3...)
le = LabelEncoder()
obe_cleaned['Target'] = le.fit_transform(obe_cleaned['NObeyesdad'])

# Print the mapping dictionary for your report reference
obesity_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Numeric mapping for Obesity Levels:\n", obesity_mapping)

# 2. Separate features (X) and the target variable (y)
X = obe_cleaned.drop(columns=['NObeyesdad', 'Target'])
y = obe_cleaned['Target']

# 3. Apply One-Hot Encoding to categorical features (e.g., Gender, SMOKE)
# drop_first=True prevents the dummy variable trap (multicollinearity)
X_encoded = pd.get_dummies(X, drop_first=True)

print("\nFirst two rows of the encoded features (X_encoded):")
display(X_encoded.head(2))
# Out:
# Numeric mapping for Obesity Levels:
#  {'Insufficient_Weight': np.int64(0), 'Normal_Weight': np.int64(1), 'Obesity_Type_I': np.int64(2), 'Obesity_Type_II': np.int64(3), 'Obesity_Type_III': np.int64(4), 'Overweight_Level_I': np.int64(5), 'Overweight_Level_II': np.int64(6)}
#
# First two rows of the encoded features (X_encoded):
#          Age  Height     Weight  FCVC  NCP  CH2O  FAF  TUE  Gender_Male  \
# 0  18.558106    1.62  23.110524   2.0  3.0   2.0  0.0  1.0        False
# 1   7.737623    1.52  80.198638   3.0  3.0   3.0  3.0  0.0        False
#
#    FAVC_yes  ...  CAEC_no  SMOKE_yes  SCC_yes  CALC_Frequently  \
# 0     False  ...    False      False    False            False
# 1     False  ...    False       True     True            False
#
#    CALC_Sometimes  CALC_no  MTRANS_Bike  MTRANS_Motorbike  \
# 0           False     True        False             False
# 1            True    False        False             False
#
#    MTRANS_Public_Transportation  MTRANS_Walking
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Apply standardization to scale all features to a similar range
# (Mean = 0, Standard Deviation = 1)
X_scaled = pd.DataFrame(scaler.fit_transform(X_encoded), columns=X_encoded.columns)

print("Standardization complete! First two rows of scaled features (X_scaled):")
display(X_scaled.head(2))
# Out:
# Standardization complete! First two rows of scaled features (X_scaled):
#         Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# 0 -0.318818 -0.875589 -1.707312 -0.785019  0.404153 -0.013073 -1.188039
# 1 -0.977827 -1.947599 -0.155277  1.088342  0.404153  1.618759  2.339750
#
#         TUE  Gender_Male  FAVC_yes  ...   CAEC_no  SMOKE_yes   SCC_yes  \
# 0  0.561997    -1.011914 -2.759769  ... -0.157344  -0.145900 -0.218272
# 1 -1.080625    -1.011914 -2.759769  ... -0.157344   6.853997  4.581439
#
#    CALC_Frequently  CALC_Sometimes   CALC_no  MTRANS_Bike  MTRANS_Motorbike  \
# 0        -0.185194       -1.404720  1.517761     -0.05768         -0.072375
# 1        -0.185194        0.711885 -0.658865     -0.05768         -0.072375
#
#    MTRANS_Public_Transportation  MTRANS_Walking
# 0                      0.579721       -0.165078
# 1                      0.579721       -0.165078
#
# [2 rows x 22 columns]

# %%
# ============================================================
# CLEAN OUTLIERS USING IQR CAPPING
# Age, Height, Weight
# ============================================================

import pandas as pd

features = ['Age', 'Height', 'Weight']

for column in features:

    # Calculate Q1 and Q3
    Q1 = obe_cleaned[column].quantile(0.25)
    Q3 = obe_cleaned[column].quantile(0.75)

    # Calculate IQR
    IQR = Q3 - Q1

    # Define lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Count outliers before cleaning
    outlier_count = (
        (obe_cleaned[column] < lower_bound) |
        (obe_cleaned[column] > upper_bound)
    ).sum()

    print(f"\n{column}")
    print(f"Lower Bound: {lower_bound:.2f}")
    print(f"Upper Bound: {upper_bound:.2f}")
    print(f"Outliers Before Cleaning: {outlier_count}")

    # --------------------------------------------------------
    # CAPPING METHOD
    # Values below lower bound become lower bound
    # Values above upper bound become upper bound
    # --------------------------------------------------------

    obe_cleaned[column] = obe_cleaned[column].clip(
        lower=lower_bound,
        upper=upper_bound
    )


print("\nOutlier capping completed.")
# Out:
# Age
# Lower Bound: -20.05
# Upper Bound: 67.71
# Outliers Before Cleaning: 16
#
# Height
# Lower Bound: 1.42
# Upper Bound: 1.98
# Outliers Before Cleaning: 1
#
# Weight
# Lower Bound: -19.71
# Upper Bound: 191.89
# Outliers Before Cleaning: 5
#
# Outlier capping completed.

# %%
# ============================================================
# CLEAN OUTLIERS USING IQR CAPPING
# Age, Height, Weight
# ============================================================

import pandas as pd

features = ['Age', 'Height', 'Weight']

for column in features:

    # Calculate Q1 and Q3
    Q1 = obe_cleaned[column].quantile(0.25)
    Q3 = obe_cleaned[column].quantile(0.75)

    # Calculate IQR
    IQR = Q3 - Q1

    # Define lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Count outliers before cleaning
    outlier_count = (
        (obe_cleaned[column] < lower_bound) |
        (obe_cleaned[column] > upper_bound)
    ).sum()

    print(f"\n{column}")
    print(f"Lower Bound: {lower_bound:.2f}")
    print(f"Upper Bound: {upper_bound:.2f}")
    print(f"Outliers Before Cleaning: {outlier_count}")

    # --------------------------------------------------------
    # CAPPING METHOD
    # Values below lower bound become lower bound
    # Values above upper bound become upper bound
    # --------------------------------------------------------

    obe_cleaned[column] = obe_cleaned[column].clip(
        lower=lower_bound,
        upper=upper_bound
    )


print("\nOutlier capping completed.")
# Out:
# Age
# Lower Bound: -20.05
# Upper Bound: 67.71
# Outliers Before Cleaning: 0
#
# Height
# Lower Bound: 1.42
# Upper Bound: 1.98
# Outliers Before Cleaning: 0
#
# Weight
# Lower Bound: -19.71
# Upper Bound: 191.89
# Outliers Before Cleaning: 0
#
# Outlier capping completed.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print(f"Training set size: {X_train.shape[0]} rows (80%)")
print(f"Testing set size: {X_test.shape[0]} rows (20%)")
# Out:
# Training set size: 1688 rows (80%)
# Testing set size: 423 rows (20%)

# %%
scaler.fit_transform(X_encoded)
# Out:
# array([[-0.3188183 , -0.87558934, -1.70731213, ..., -0.07237469,
#          0.57972058, -0.16507758],
#        [-0.97782715, -1.94759928, -0.15527705, ..., -0.07237469,
#          0.57972058, -0.16507758],
#        [-2.41295715,  1.05402854, -0.31753858, ..., -0.07237469,
#          0.57972058, -0.16507758],
#        ...,
#        [-0.20004283,  0.54167211,  1.61714397, ..., -0.07237469,
#          0.57972058, -0.16507758],
#        [-0.03423713,  0.40492652,  1.46447547, ..., -0.07237469,
#          0.57972058, -0.16507758],
#        [ 1.50773053,  0.39834438,  1.48290672, ..., -0.07237469,
#          0.57972058, -0.16507758]])

# %%
# 1. Encode
X_encoded = pd.get_dummies(X, drop_first=True)

# 2. Split FIRST
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# 3. Scale AFTER split
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

# IMPORTANT: only transform test data
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import GridSearchCV, StratifiedKFold

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# %%
# ============================================================
# 1. CROSS VALIDATION
# ============================================================

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
# ============================================================
# MODEL 1 - DECISION TREE (BASELINE)
# ============================================================

dt_model = DecisionTreeClassifier(
    max_depth=3,
    min_samples_split=5,
    random_state=42
)

dt_model.fit(
    X_train_scaled,
    y_train
)

dt_pred = dt_model.predict(
    X_test_scaled
)

# %%
# ============================================================
#  MODEL 2 - GAUSSIAN NAIVE BAYES
# ============================================================

nb_model = GaussianNB()

# Number of classes in the training data
n_classes = len(np.unique(y_train))

# Equal prior probability for every obesity class
equal_priors = [1 / n_classes] * n_classes


nb_param_grid = {

    'var_smoothing': np.logspace(-12, -6, 13),

    'priors': [
        None,
        equal_priors
    ]
}


nb_grid = GridSearchCV(
    estimator=nb_model,
    param_grid=nb_param_grid,
    scoring='f1_macro',
    cv=cv,
    n_jobs=-1
)


nb_grid.fit(
    X_train_scaled,
    y_train
)


best_nb = nb_grid.best_estimator_


nb_pred = best_nb.predict(
    X_test_scaled
)

# %%
# ============================================================
#  MODEL 3 - LOGISTIC REGRESSION
# ============================================================

lr_model = LogisticRegression(
    max_iter=3000,
    random_state=42
)


lr_param_grid = {

    # Parameter 1
    'C': [
        0.01,
        0.1,
        1,
        10,
        100
    ],

    # Parameter 2
    'solver': [
        'lbfgs',
        'newton-cg'
    ]
}


lr_grid = GridSearchCV(
    estimator=lr_model,
    param_grid=lr_param_grid,
    scoring='f1_macro',
    cv=cv,
    n_jobs=-1
)


lr_grid.fit(
    X_train_scaled,
    y_train
)


best_lr = lr_grid.best_estimator_


lr_pred = best_lr.predict(
    X_test_scaled
)

# %%
# ============================================================
# 5. DISPLAY BEST PARAMETERS
# ============================================================

print("=" * 65)
print("MODEL CONFIGURATION / BEST PARAMETERS")
print("=" * 65)

print("\nDecision Tree Baseline")
print("max_depth = 3")

print("\nBest Naive Bayes Parameters:")
print(nb_grid.best_params_)

print(
    "Naive Bayes CV Macro F1:",
    f"{nb_grid.best_score_ * 100:.2f}%"
)

print("\nBest Logistic Regression Parameters:")
print(lr_grid.best_params_)

print(
    "Logistic Regression CV Macro F1:",
    f"{lr_grid.best_score_ * 100:.2f}%"
)
# Out:
# ...
# MODEL CONFIGURATION / BEST PARAMETERS
# ...
#
# Decision Tree Baseline
# max_depth = 3
#
# Best Naive Bayes Parameters:
# {'priors': None, 'var_smoothing': np.float64(1e-06)}
# Naive Bayes CV Macro F1: 39.70%
#
# Best Logistic Regression Parameters:
# {'C': 10, 'solver': 'lbfgs'}
# Logistic Regression CV Macro F1: 57.57%

# %%
# ============================================================
# 7. CONFUSION MATRIX EVALUATION FUNCTION
# ============================================================

def evaluate_from_confusion_matrix(
    model_name,
    y_true,
    y_pred
):

    # ---------------------------------------------
    # Create multiclass confusion matrix
    # ---------------------------------------------

    class_labels = np.unique(y_true)

    cm = confusion_matrix(
        y_true,
        y_pred,
        labels=class_labels
    )


    total_samples = cm.sum()

    class_results = []


    # ---------------------------------------------
    # Calculate each class separately
    # ---------------------------------------------

    for i, class_name in enumerate(
        class_labels
    ):

        # =========================================
        # TRUE POSITIVE
        # =========================================

        TP = cm[i, i]


        # =========================================
        # FALSE NEGATIVE
        # =========================================
        #
        # Actual class = current class
        # Predicted = another class
        #

        FN = (
            cm[i, :].sum()
            - TP
        )


        # =========================================
        # FALSE POSITIVE
        # =========================================
        #
        # Actual = another class
        # Predicted = current class
        #

        FP = (
            cm[:, i].sum()
            - TP
        )


        # =========================================
        # TRUE NEGATIVE
        # =========================================

        TN = (
            total_samples
            - TP
            - FP
            - FN
        )


        # =========================================
        # PRECISION
        # =========================================

        if (TP + FP) > 0:

            precision = (
                TP /
                (TP + FP)
            )

        else:

            precision = 0


        # =========================================
        # RECALL / SENSITIVITY
        # =========================================

        if (TP + FN) > 0:

            recall = (
                TP /
                (TP + FN)
            )

        else:

            recall = 0


        # =========================================
        # SPECIFICITY
        # =========================================

        if (TN + FP) > 0:

            specificity = (
                TN /
                (TN + FP)
            )

        else:

            specificity = 0


        # =========================================
        # ONE-VS-REST ACCURACY
        # =========================================

        accuracy_class = (
            (TP + TN) /
            (
                TP
                + TN
                + FP
                + FN
            )
        )


        # =========================================
        # F1-SCORE
        # =========================================

        if (
            precision + recall
        ) > 0:

            f1 = (
                2
                * precision
                * recall
                /
                (
                    precision
                    + recall
                )
            )

        else:

            f1 = 0


        # =========================================
        # SAVE CLASS RESULT
        # =========================================

        class_results.append({

            'Class': class_name,

            'TP': TP,
            'TN': TN,
            'FP': FP,
            'FN': FN,

            'Accuracy': accuracy_class,

            'Precision': precision,

            'Recall': recall,

            'Specificity': specificity,

            'F1-Score': f1
        })


    # Convert into dataframe
    class_df = pd.DataFrame(
        class_results
    )


    # ========================================================
    # OVERALL MULTICLASS ACCURACY
    # =======================================================

    overall_accuracy = (
        np.trace(cm)
        /
        cm.sum()
    )


    # ========================================================
    # MACRO AVERAGE
    # ========================================================

    macro_precision = (
        class_df[
            'Precision'
        ].mean()
    )


    macro_recall = (
        class_df[
            'Recall'
        ].mean()
    )


    macro_specificity = (
        class_df[
            'Specificity'
        ].mean()
    )


    macro_f1 = (
        class_df[
            'F1-Score'
        ].mean()
    )


    overall_result = {

        'Model': model_name,

        'Accuracy':
            overall_accuracy,

        'Macro Precision':
            macro_precision,

        'Macro Recall':
            macro_recall,

        'Macro Specificity':
            macro_specificity,

        'Macro F1-Score':
            macro_f1
    }


    return (
        overall_result,
        class_df,
        cm,
        class_labels
    )

# %%
# ============================================================
# 8. EVALUATE DECISION TREE
# ============================================================

(
    dt_result,
    dt_class_results,
    dt_cm,
    dt_classes
) = evaluate_from_confusion_matrix(

    'Decision Tree (Baseline)',

    y_test,

    dt_pred
)

# %%
# ============================================================
# 9. EVALUATE NAIVE BAYES
# ============================================================

(
    nb_result,
    nb_class_results,
    nb_cm,
    nb_classes
) = evaluate_from_confusion_matrix(

    'Gaussian Naive Bayes',

    y_test,

    nb_pred
)

# %%
# ============================================================
# 10. EVALUATE LOGISTIC REGRESSION
# ============================================================

(
    lr_result,
    lr_class_results,
    lr_cm,
    lr_classes
) = evaluate_from_confusion_matrix(

    'Logistic Regression',

    y_test,

    lr_pred
)

# %%
# ============================================================
# 11. OVERALL PERFORMANCE DATAFRAME
# ============================================================

results_df = pd.DataFrame([

    dt_result,

    nb_result,

    lr_result

])

# %%
# ============================================================
# 12. DISPLAY OVERALL RESULTS AS PERCENTAGE
# ============================================================

results_percentage = (
    results_df.copy()
)


metric_columns = [

    'Accuracy',

    'Macro Precision',

    'Macro Recall',

    'Macro Specificity',

    'Macro F1-Score'
]


for col in metric_columns:

    results_percentage[col] = (

        results_percentage[col]

        * 100

    ).round(2).astype(str) + '%'


print("\n")
print("=" * 90)
print(
    "OVERALL PERFORMANCE COMPARISON OF MACHINE LEARNING MODELS"
)
print("=" * 90)


display(
    results_percentage
)
# Out:
# ...
# OVERALL PERFORMANCE COMPARISON OF MACHINE LEARNING MODELS
# ...
#                       Model Accuracy Macro Precision Macro Recall  \
# 0  Decision Tree (Baseline)   45.11%          40.44%       44.59%
# 1      Gaussian Naive Bayes   46.85%          44.72%       45.82%
# 2       Logistic Regression   56.94%          55.21%       56.31%
#
#   Macro Specificity Macro F1-Score
# 0            90.84%         40.67%
# 1            91.13%         40.02%
# 2            92.82%         55.28%

# %%
# ============================================================
# 13. FIND BEST MODEL
# ============================================================

best_index = (

    results_df[
        'Macro F1-Score'
    ].idxmax()

)


best_model_name = (

    results_df.loc[
        best_index,
        'Model'
    ]

)


best_model_f1 = (

    results_df.loc[
        best_index,
        'Macro F1-Score'
    ]

)


print("\nBest Model Based on Macro F1-Score:")

print(

    best_model_name,

    "-",

    f"{best_model_f1 * 100:.2f}%"

)
# Out:
# Best Model Based on Macro F1-Score:
# Logistic Regression - 55.28%

# %%
# ============================================================
# 14. MAIN PERFORMANCE COMPARISON GRAPH
# ============================================================

plot_metrics = [

    'Accuracy',

    'Macro Precision',

    'Macro Recall',

    'Macro F1-Score'

]


plot_df = (
    results_df[
        ['Model'] + plot_metrics
    ].copy()
)


# Convert values into percentage
for col in plot_metrics:

    plot_df[col] = (
        plot_df[col] * 100
    )


plot_df = (
    plot_df
    .set_index('Model')
)


ax = plot_df.plot(

    kind='bar',

    figsize=(13, 7),

    width=0.75

)


plt.title(

    'Overall Performance Comparison of Machine Learning Models',

    fontsize=15,

    pad=15

)


plt.xlabel(

    'Machine Learning Model',

    fontsize=12

)


plt.ylabel(

    'Performance Score (%)',

    fontsize=12

)


plt.ylim(
    0,
    108
)


plt.xticks(

    rotation=0,

    fontsize=10

)


plt.legend(

    title='Evaluation Metrics',

    loc='lower right'

)


# Add percentage above every bar
for container in ax.containers:

    labels = []

    for bar in container:

        height = bar.get_height()

        labels.append(

            f'{height:.1f}%'

        )

    ax.bar_label(

        container,

        labels=labels,

        padding=3,

        fontsize=9

    )


plt.tight_layout()

plt.show()

# %%
# ============================================================
# 15. DECISION TREE CONFUSION MATRIX
# ============================================================

disp_dt = ConfusionMatrixDisplay(

    confusion_matrix=dt_cm,

    display_labels=dt_classes

)


disp_dt.plot(

    cmap='Blues',

    xticks_rotation=45

)


plt.title(

    'Decision Tree (Baseline) - Confusion Matrix'

)


plt.xlabel(
    'Predicted Class'
)

plt.ylabel(
    'Actual Class'
)


plt.tight_layout()

plt.show()

# %%
# ============================================================
# 16. NAIVE BAYES CONFUSION MATRIX
# ============================================================

disp_nb = ConfusionMatrixDisplay(

    confusion_matrix=nb_cm,

    display_labels=nb_classes

)


disp_nb.plot(

    cmap='Blues',

    xticks_rotation=45

)


plt.title(

    'Gaussian Naive Bayes - Confusion Matrix'

)


plt.xlabel(
    'Predicted Class'
)

plt.ylabel(
    'Actual Class'
)


plt.tight_layout()

plt.show()

# %%
# ============================================================
# 17. LOGISTIC REGRESSION CONFUSION MATRIX
# ============================================================

disp_lr = ConfusionMatrixDisplay(

    confusion_matrix=lr_cm,

    display_labels=lr_classes

)


disp_lr.plot(

    cmap='Blues',

    xticks_rotation=45

)


plt.title(

    'Logistic Regression - Confusion Matrix'

)


plt.xlabel(
    'Predicted Class'
)

plt.ylabel(
    'Actual Class'
)


plt.tight_layout()

plt.show()

# %%
from sklearn.metrics import confusion_matrix

# ============================================================
# 1. FUNCTION TO CALCULATE PER-CLASS METRICS
# ============================================================

def get_per_class_confusion_metrics(
    model_name,
    y_true,
    y_pred
):

    # Get all classes
    class_labels = np.unique(y_true)

    # Create multiclass confusion matrix
    cm = confusion_matrix(
        y_true,
        y_pred,
        labels=class_labels
    )

    total_samples = cm.sum()

    rows = []


    # ========================================================
    # LOOP THROUGH EACH CLASS
    # ========================================================

    for i, class_name in enumerate(class_labels):

        TP = cm[i, i]

        FN = (
            cm[i, :].sum()
            - TP
        )

        FP = (
            cm[:, i].sum()
            - TP
        )

        TN = (
            total_samples
            - TP
            - FP
            - FN
        )


        # ====================================================
        # ACCURACY
        # ====================================================

        accuracy = (
            (TP + TN)
            /
            (TP + TN + FP + FN)
        )


        # ====================================================
        # PRECISION
        # ====================================================

        if (TP + FP) > 0:

            precision = (
                TP
                /
                (TP + FP)
            )

        else:

            precision = 0


        # ====================================================
        # RECALL
        # ====================================================

        if (TP + FN) > 0:

            recall = (
                TP
                /
                (TP + FN)
            )

        else:

            recall = 0


        # ====================================================
        # F1-SCORE
        # ====================================================

        if (precision + recall) > 0:

            f1 = (
                2
                * precision
                * recall
                /
                (precision + recall)
            )

        else:

            f1 = 0


        # ====================================================
        # ADD ONE ROW
        # ====================================================

        rows.append({

            'Model': model_name,

            'Class': class_name,

            'TP': TP,

            'TN': TN,

            'FP': FP,

            'FN': FN,

            'Accuracy': accuracy,

            'Precision': precision,

            'Recall': recall,

            'F1-Score': f1
        })


    return pd.DataFrame(rows)


# ============================================================
# 2. DECISION TREE
# ============================================================

dt_details = get_per_class_confusion_metrics(
    'Decision Tree',
    y_test,
    dt_pred
)


# ============================================================
# 3. NAIVE BAYES
# ============================================================

nb_details = get_per_class_confusion_metrics(
    'Naive Bayes',
    y_test,
    nb_pred
)


# ============================================================
# 4. LOGISTIC REGRESSION
# ============================================================

lr_details = get_per_class_confusion_metrics(
    'Logistic Regression',
    y_test,
    lr_pred
)


# ============================================================
# 5. COMBINE ALL MODELS
# ============================================================

all_21_results = pd.concat(
    [
        dt_details,
        nb_details,
        lr_details
    ],
    ignore_index=True
)


# ============================================================
# 6. DISPLAY AS DECIMAL
# ============================================================

display(
    all_21_results.round(4)
)
# Out:
#                   Model  Class  TP   TN   FP  FN  Accuracy  Precision  Recall  \
# 0         Decision Tree      0  40  513   39  42    0.8722     0.5063  0.4878
# 1         Decision Tree      1  10  528   20  76    0.8486     0.3333  0.1163
# 2         Decision Tree      2  36  455   73  70    0.7744     0.3303  0.3396
# 3         Decision Tree      3  60  486   59  29    0.8612     0.5042  0.6742
# 4         Decision Tree      4  89  527   10   8    0.9716     0.8990  0.9175
# 5         Decision Tree      5  51  400  147  36    0.7114     0.2576  0.5862
# 6         Decision Tree      6   0  547    0  87    0.8628     0.0000  0.0000
# 7           Naive Bayes      0  44  494   58  38    0.8486     0.4314  0.5366
# 8           Naive Bayes      1   7  532   16  79    0.8502     0.3043  0.0814
# 9           Naive Bayes      2  50  455   73  56    0.7965     0.4065  0.4717
# 10          Naive Bayes      3  83  382  163   6    0.7334     0.3374  0.9326
# ...

# %%
# ============================================================
# FIND THE BEST MODEL
# Based on Macro F1-Score
# ============================================================

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

import pandas as pd


# ============================================================
# 1. EVALUATION FUNCTION
# ============================================================

def evaluate_model(model_name, y_true, y_pred):

    accuracy = accuracy_score(
        y_true,
        y_pred
    )

    precision = precision_score(
        y_true,
        y_pred,
        average='macro',
        zero_division=0
    )

    recall = recall_score(
        y_true,
        y_pred,
        average='macro',
        zero_division=0
    )

    f1 = f1_score(
        y_true,
        y_pred,
        average='macro',
        zero_division=0
    )

    return {
        'Model': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision,
        'Macro Recall': recall,
        'Macro F1-Score': f1
    }


# ============================================================
# 2. CALCULATE RESULTS FOR ALL MODELS
# ============================================================

dt_result = evaluate_model(
    'Decision Tree',
    y_test,
    dt_pred
)

nb_result = evaluate_model(
    'Naive Bayes',
    y_test,
    nb_pred
)

lr_result = evaluate_model(
    'Logistic Regression',
    y_test,
    lr_pred
)


# ============================================================
# 3. CREATE RESULT TABLE
# ============================================================

results_df = pd.DataFrame([
    dt_result,
    nb_result,
    lr_result
])


# ============================================================
# 4. DISPLAY AS PERCENTAGE
# ============================================================

results_display = results_df.copy()

metric_columns = [
    'Accuracy',
    'Macro Precision',
    'Macro Recall',
    'Macro F1-Score'
]

for col in metric_columns:

    results_display[col] = (
        results_display[col] * 100
    ).round(2).astype(str) + '%'


print("=" * 90)
print("MODEL PERFORMANCE COMPARISON")
print("=" * 90)

display(results_display)


# ============================================================
# 5. FIND BEST MODEL
# ============================================================

best_index = results_df[
    'Macro F1-Score'
].idxmax()

best_model_name = results_df.loc[
    best_index,
    'Model'
]

best_accuracy = results_df.loc[
    best_index,
    'Accuracy'
]

best_precision = results_df.loc[
    best_index,
    'Macro Precision'
]

best_recall = results_df.loc[
    best_index,
    'Macro Recall'
]

best_f1 = results_df.loc[
    best_index,
    'Macro F1-Score'
]


print("\n")
print("=" * 70)
print("BEST MACHINE LEARNING MODEL")
print("=" * 70)

print(
    f"Best Model      : {best_model_name}"
)

print(
    f"Accuracy        : {best_accuracy * 100:.2f}%"
)

print(
    f"Macro Precision : {best_precision * 100:.2f}%"
)

print(
    f"Macro Recall    : {best_recall * 100:.2f}%"
)

print(
    f"Macro F1-Score  : {best_f1 * 100:.2f}%"
)
# Out:
# ...
# MODEL PERFORMANCE COMPARISON
# ...
#                  Model Accuracy Macro Precision Macro Recall Macro F1-Score
# 0        Decision Tree   45.11%          40.44%       44.59%         40.67%
# 1          Naive Bayes   46.85%          44.72%       45.82%         40.02%
# 2  Logistic Regression   56.94%          55.21%       56.31%         55.28%
# ...
# BEST MACHINE LEARNING MODEL
# ...
# Best Model      : Logistic Regression
# Accuracy        : 56.94%
# Macro Precision : 55.21%
# Macro Recall    : 56.31%
# Macro F1-Score  : 55.28%

# %%
import joblib

joblib.dump(
    best_lr,
    "best_obesity_model.pkl"
)

joblib.dump(
    scaler,
    "scaler.pkl"
)

joblib.dump(
    le,
    "label_encoder.pkl"
)

joblib.dump(
    X_encoded.columns.tolist(),
    "feature_columns.pkl"
)

print("Best model and preprocessing objects saved successfully.")
# Out:
# Best model and preprocessing objects saved successfully.
